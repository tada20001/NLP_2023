# %% [markdown]
# <a href="https://colab.research.google.com/github/tada20001/NLP_2023/blob/main/19_08_BERTopic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bertopic[visualization]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic[visualization]
#   Downloading bertopic-0.15.0-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.4/143.4 kB 4.6 MB/s eta 0:00:00
# WARNING: bertopic 0.15.0 does not provide the extra 'visualization'
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (1.22.4)
# Collecting hdbscan>=0.8.29 (from bertopic[visualization])
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 64.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting umap-learn>=0.5.0 (from bertopic[visualization])
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 14.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (1.2.2)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (4.65.0)
# Collecting sentence-transformers>=0.4.1 (from bertopic[visualization])
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (5.13.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (0.29.34)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.10.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers>=0.4.1->bertopic[visualization])
#   Downloading transformers-4.30.1-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 112.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (3.8.1)
# Collecting sentencepiece (from sentence-transformers>=0.4.1->bertopic[visualization])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 89.5 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers>=0.4.1->bertopic[visualization])
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 31.3 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.56.4)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic[visualization])
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 86.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (23.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic[visualization]) (67.7.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.1.5->bertopic[visualization]) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (16.0.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization])
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 42.0 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic[visualization])
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.3 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic[visualization]) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic[visualization]) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.3.0)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp310-cp310-linux_x86_64.whl size=3541991 sha256=dcee1ace812f142e77fbf1d83e135858bc004152e350b9154ece6051feb74028
#   Stored in directory: /root/.cache/pip/wheels/dc/52/e3/6c6b60b126b4d5c4370cb5ac071b82950f91649d62d72f7f56
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=2529c9e8d1116753cce39804f9babfbc9cd99663aa48c605667e81b13a675119
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82816 sha256=557e6a5791e11da06d4317e51f47400863fcb1841b0f8c95fa5e142f61fcfdbb
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55622 sha256=01c55ea6d7d078cc10959379498832f05c8bf78ff30672388ca73017c513462a
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, safetensors, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.15.0 hdbscan-0.8.29 huggingface-hub-0.15.1 pynndescent-0.5.10 safetensors-0.3.1 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.30.1 umap-learn-0.5.3

# %% [markdown]
# ### 1. BERTopic
# ------------
# BERT embeddings와 클래스 기반(class-based) TF-IDF를 활용한 알고리즘으로 클러스터를 만드는 토픽모델링 기술임.
# 다음의 3가지 과정을 거침.
#
# 1) SBERT로 임베딩
# * “paraphrase‑MiniLM‑L6‑v2” : 영어 데이터로 학습된 SBERT
# * “paraphrase‑multilingual‑MiniLM‑L12‑v2” : 50 개 이상의 언어로 학습된 다국어 SBERT
#
# 2) 문서 클러스터링 : UMAP을 사용하여 임베딩 차원을 줄이고 HDBSCAN 알고리즘을 이용하여 차원 축소된 임베딩을 클러스터링하고 의미적으로 유사한 문서 클러스터를 생성함
#
# 3) 토픽표현 생성 : 클래스 기반 TF-IDF 토픽 추출
#
#
# ### 2. 데이터 로드
# -------------------

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))['data']
docs[:5]
# Out:
# ["\n\nI am sure some bashers of Pens fans are pretty confused about the lack\nof any kind of posts about the recent Pens massacre of the Devils. Actually,\nI am  bit puzzled too and a bit relieved. However, I am going to put an end\nto non-PIttsburghers' relief with a bit of praise for the Pens. Man, they\nare killing those Devils worse than I thought. Jagr just showed you why\nhe is much better than his regular season stats. He is also a lot\nfo fun to watch in the playoffs. Bowman should let JAgr have a lot of\nfun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final\nregular season game.          PENS RULE!!!\n\n",
#  'My brother is in the market for a high-performance video card that supports\nVESA local bus with 1-2MB RAM.  Does anyone have suggestions/ideas on:\n\n  - Diamond Stealth Pro Local Bus\n\n  - Orchid Farenheit 1280\n\n  - ATI Graphics Ultra Pro\n\n  - Any other high-performance VLB card\n\n\nPlease post or email.  Thank you!\n\n  - Matt\n',
#  '\n\n\n\n\tFinally you said what you dream about. Mediterranean???? That was new....\n\tThe area will be "greater" after some years, like your "holocaust" numbers......\n\n\n\n\n\t\t*****\n\tIs\'t July in USA now????? Here in Sweden it\'s April and still cold.\n\tOr have you changed your calendar???\n\n\n\t\t\t\t\t\t    ****************\n\t\t\t\t\t\t    ******************\n\t\t\t    ***************\n\n\n\tNOTHING OF THE MENTIONED IS TRUE, BUT LET SAY IT\'s TRUE.\n\t\n\tSHALL THE AZERI WOMEN AND CHILDREN GOING TO PAY THE PRICE WITH\n\t\t\t\t\t\t    **************\n\tBEING RAPED, KILLED AND TORTURED BY THE ARMENIANS??????????\n\t\n\tHAVE YOU HEARDED SOMETHING CALLED: "GENEVA CONVENTION"???????\n\tYOU FACIST!!!!!\n\n\n\n\tOhhh i forgot, this is how Armenians fight, nobody has forgot\n\tyou killings, rapings and torture against the Kurds and Turks once\n\tupon a time!\n      \n       \n\n\nOhhhh so swedish RedCross workers do lie they too? What ever you say\n"regional killer", if you don\'t like the person then shoot him that\'s your policy.....l\n\n\n\t\t\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n\tConfused?????\t\t\t\t\t\t\t\ti\n\t\t\t\t\t\t\t\t\t\ti\n        Search Turkish planes? You don\'t know what you are talking about.\ti\n        Turkey\'s government has announced that it\'s giving weapons  <-----------i\n        to Azerbadjan since Armenia started to attack Azerbadjan\t\t\n        it self, not the Karabag province. So why search a plane for weapons\t\n        since it\'s content is announced to be weapons?   \n\n\tIf there is one that\'s confused then that\'s you! We have the right (and we do)\n\tto give weapons to the Azeris, since Armenians started the fight in Azerbadjan!\n \n\n\n\tShoot down with what? Armenian bread and butter? Or the arms and personel \n\tof the Russian army?\n\n\n',
#  "\nThink!\n\nIt's the SCSI card doing the DMA transfers NOT the disks...\n\nThe SCSI card can do DMA transfers containing data from any of the SCSI devices\nit is attached when it wants to.\n\nAn important feature of SCSI is the ability to detach a device. This frees the\nSCSI bus for other devices. This is typically used in a multi-tasking OS to\nstart transfers on several devices. While each device is seeking the data the\nbus is free for other commands and data transfers. When the devices are\nready to transfer the data they can aquire the bus and send the data.\n\nOn an IDE bus when you start a transfer the bus is busy until the disk has seeked\nthe data and transfered it. This is typically a 10-20ms second lock out for other\nprocesses wanting the bus irrespective of transfer time.\n",
#  '1)    I have an old Jasmine drive which I cannot use with my new system.\n My understanding is that I have to upsate the driver with a more modern\none in order to gain compatability with system 7.0.1.  does anyone know\nof an inexpensive program to do this?  ( I have seen formatters for <$20\nbuit have no idea if they will work)\n \n2)     I have another ancient device, this one a tape drive for which\nthe back utility freezes the system if I try to use it.  THe drive is a\njasmine direct tape (bought used for $150 w/ 6 tapes, techmar\nmechanism).  Essentially I have the same question as above, anyone know\nof an inexpensive beckup utility I can use with system 7.0.1']

# %%
len(docs)
# Out:
# 18846

# %% [markdown]
# ### 3. 토픽모델링
# ---------------
# BERTopic 모델 객체를 만들고, fit_transform 수행

# %%
model = BERTopic()
topics, probabilities = model.fit_transform(docs)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
print('각 문서의 토픽번호 리스트:', len(topics))
print('첫번째 문서의 토픽번호:',topics[0])
# Out:
# 각 문서의 토픽번호 리스트: 18846
# 첫번째 문서의 토픽번호: 0

# %%
# 토픽의 개수, 크기, 각 토픽에 할당된 단어 확인 가능
model.get_topic_info()
# Out:
#      Topic  Count                                Name  \
# 0       -1   6649                     -1_to_is_of_the
# 1        0   1824                0_game_team_games_he
# 2        1    563       1_key_clipper_chip_encryption
# 3        2    525                2_ites_cheek_yep_huh
# 4        3    438        3_monitor_card_video_drivers
# ..     ...    ...                                 ...
# 209    208     10          208_media_nw_washington_dc
# 210    209     10  209_toshiba_nec_drive_cdtechnology
# 211    210     10         210_law_jesus_paul_gentiles
# 212    211     10  211_uninstall_windows_norton_group
# 213    212     10      212_paradox_borland_sql_engine
#
#                                         Representation  \
# 0       [to, is, of, the, and, you, for, in, it, this]
# 1    [game, team, games, he, players, season, hocke...
# 2    [key, clipper, chip, encryption, keys, escrow,...
# 3    [ites, cheek, yep, huh, ken, why, each, very, ...
# 4    [monitor, card, video, drivers, vga, monitors,...
# ..                                                 ...
# 209  [media, nw, washington, dc, street, news, ny, ...
# 210  [toshiba, nec, drive, cdtechnology, 3401, mult...
# 211  [law, jesus, paul, gentiles, faith, heaven, go...
# 212  [uninstall, windows, norton, group, 31, deskto...
# 213  [paradox, borland, sql, engine, database, odbc...
#
#                                    Representative_Docs
# 0    [\n\n\tWhy do we follow God so blindly?  Have ...
# 1    [NHL RESULTS FOR GAMES PLAYED 4/15/93.\n\n----...
# 2    [Here is a revised version of my summary which...
# 3                            [\nHuh?, \nYep.\n, ites:]
# 4    [A couple of months ago I tried out a Hercules...
# ..                                                 ...
# 209  [From article <1qvampINNmhf@darkstar.UCSC.EDU>...
# 210  [The Toshiba has a 200ms access time, the NEC ...
# 211  [\nOK, here's at least one Christian's answer:...
# 212  [(NDW)\n\nIf an Uninstall icon doesn't exist i...
# 213  [[ Article crossposted from comp.os.ms-windows...
#
# [214 rows x 5 columns]

# %%
# count열의 값을 합치면 총문서의 수가 됨
model.get_topic_info()['Count'].sum()
# Out:
# 18846

# %% [markdown]
# Topic -1이 가장 크나, 토픽이 할당되지 않은 이상치에 해당하는 문서들임. 따라서 토픽은 0-210까지 있는 것임.

# %%
# 3번 토픽 정보
model.get_topic(3)
# Out:
# [('monitor', 0.022295341872923997),
#  ('card', 0.02167927164641604),
#  ('video', 0.015727636934186322),
#  ('drivers', 0.012620073296151302),
#  ('vga', 0.012602969688873656),
#  ('monitors', 0.009620979290856008),
#  ('diamond', 0.009068046739958546),
#  ('screen', 0.008915507120835244),
#  ('cards', 0.008491358410794408),
#  ('mode', 0.008242045760807526)]

# %% [markdown]
# ### 4. 토픽 시각화
# ----------
# BERTopic을 사용하면 LDAvis와 매우 유사한 방식으로 생성된 토픽을 시각화할 수 있음. 시각화를 통해 생성된 토픽에 대해 더 많은 통찰력을 얻을 수 있음

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="883e9bc0-7115-4c9f-9945-7b533fbe75b2" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("883e9bc0-7115-4c9f-9945-7b533fbe75b2")) {                    Plotly.newPlot(                        "883e9bc0-7115-4c9f-9945-7b533fbe75b2",                        [{"customdata":[[0,"game | team | games | he | players",1824],[1,"key | clipper | chip | encryption | keys",563],[2,"ites | cheek | yep | huh | ken",525],[3,"monitor | card | video | drivers | vga",438],[4,"fbi | batf | koresh | fire | compound",436],[5,"car | cars | engine | ford | miles",386],[6,"bike | riding | ride | my | lane",268],[7,"gun | guns | deaths | firearms | crime",160],[8,"audio | amp | condition | stereo | asking",159],[9,"bike | bikes | honda | miles | motorcycle",157],[10,"printer | print | hp | deskjet | printers",150],[11,"space | shuttle | moon | launch | nasa",138],[12,"atheists | atheism | god | atheist | belief",133],[13,"window | widget | application | event | events",131],[14,"israel
_ports","87_lebanese_israel_lebanon","88_oort_cloud_grbs","89_motif_widgets_bindings","90_water_dept_phd","91_jesus_tomb_disciples","92_trial_boomer_cement","93_usenet_internet_advertis...","94_israel_israeli_publication","95_graphics_ray_3d","96_mhz_clock_fpu","97_countersteering_bike_lean","98_jesus_christianity_chris...","99_insurance_health_private","100_font_fonts_tt","101_marriage_married_marry","102_oil_drain_car","103_celp_speech_voice","104_jehovah_elohim_lord","105_cci_horses_sale","106_deleted_stuff_deletion","107_motherboard_bios_ram","108_myers_stephanopoulos_pr...","109_data_ftp_image","110_hacker_computer_hackers","111_image_processing_analysis","112_1st_wolverine_hulk","113_leds_blue_boards","114_scanner_logitech_ocr","115_lock_kryptonite_cable","116_monitor_off_turn","117_xv_copyright_24bit","118_firearms_hb_nra","119_guide_shipping_disks","120_context_jim_you","121_chip_board_connector","122_enviroleague_homosexual...","123_yassin_irgun_deir","124_helmet_liner_foam","125_truth_absolute_bible","126_maxaxaxaxaxaxaxaxaxaxax...","127_tape_backup_drive","128_ghostscript_postscript_...","129_cancer_medical_center","130_dce_modem_dte","131_aaron_baptism_sin","132_lens_camera_nikon","133_stuffit_files_system","134_bush_quayle_panicking","135_scope_scopes_tektronix","1 ...

# %% [markdown]
# ### 7. 토픽수 정하기
# -----
# 토픽수를 직접 정하는 방법..
# 1) 모델 객체생성시 nr_topics 값으로 원하는 토픽수를 입력하여 원하는 토픽수를 설정할 수 있음. BERTopic은 유사한 토픽을 찾아 하나의 토픽으로 병합함.

# %%
model = BERTopic(nr_topics=20)

# %%
topics, probabilities = model.fit_transform(docs)

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="7cfd3b87-637d-49ff-9c8b-ddf2e1115841" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cfd3b87-637d-49ff-9c8b-ddf2e1115841")) {                    Plotly.newPlot(                        "7cfd3b87-637d-49ff-9c8b-ddf2e1115841",                        [{"customdata":[[0,"the | to | and | is | for",2668],[1,"the | of | to | and | that",2574],[2,"the | in | to | he | game",1830],[3,"the | of | that | is | to",1062],[4,"the | for | and | to | in",795],[5,"gre | test | explanations | economics | includes",560],[6,"the | to | for | is | and",458],[7,"of | the | to | and | in",418],[8,"the | and | of | to | is",386],[9,"the | to | and | you | my",378],[10,"the | space | of | to | and",377],[11,"oil | the | it | and | to",118],[12,"water | the | battery | of | to",108],[13,"kirlian | photography | the | to | of",107],[14,"maxaxaxaxaxaxaxaxaxaxaxaxaxaxax | the | den | points | of",99],[15,"of | is | the | that | to",89],[16,"fan | cpu | heat | the | on",59],[17,"cancer | center | medical | research | centers",21],[18,"ground | grounding | neutral | conductor | wire",14]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>%{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[2668,2574,1830,1062,795,560,458,418,386,378,377,118,108,107,99,89,59,21,14],"sizemode":"area","sizeref":1.6675,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[10.966541290283203,4.861598968505859,13.437413215637207,4.555324077606201,9.69614315032959,12.999478340148926,10.25926399230957,-8.35413932800293,12.513648986816406,9.415385246276855,9.302413940429688,9.775158882141113,9.835807800292969,9.333134651184082,11.168270111083984,4.398522853851318,11.160032272338867,-8.528037071228027,10.053168296813965],"xaxis":"x","y":[-5.491034030914307,10.831506729125977,-5.316890239715576,10.525617599487305,-5.00895881652832,-5.205025672912598,-5.160682678222656,4.4201979637146,-5.201353549957275,-5.077548503875732,-4.584275722503662,-2.8466198444366455,-3.2629806995391846,-4.106675148010254,-5.125281810760498,10.368661880493164,-5.695839881896973,4.592060089111328,-3.343132257461548],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":1,"tickcolor":"rgb(36,36,36)","ticks":"outside"},"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[ ...

# %% [markdown]
# 2) 또 다른 방법은 자동으로 토픽수를 줄이도록 설정하는 것임.

# %%
model = BERTopic(nr_topics="auto")
topics, probabilities = model.fit_transform(docs)

model.get_topic_info()
# Out:
#     Topic  Count                                    Name  \
# 0      -1   6557                        -1_the_to_of_and
# 1       0   2636                       0_for_with_is_the
# 2       1   1825                    1_game_team_he_games
# 3       2   1369                        2_that_of_is_god
# 4       3   1130                       3_the_key_to_that
# ..    ...    ...                                     ...
# 91     90     12   90_needles_acupuncture_needle_syringe
# 92     91     11   91_xtermmap_numlock_definekey_xmodmap
# 93     92     11  92_moscow_aviation_russian_kaliningrad
# 94     93     11             93_boards_solder_mask_green
# 95     94     11        94_plutonium_nuclear_clancy_bomb
#
#                                        Representation  \
# 0      [the, to, of, and, is, in, for, that, it, you]
# 1   [for, with, is, the, and, to, it, drive, or, you]
# 2   [game, team, he, games, the, was, in, players,...
# 3     [that, of, is, god, not, to, the, you, in, and]
# 4   [the, key, to, that, of, and, be, they, is, this]
# ..                                                ...
# 91  [needles, acupuncture, needle, syringe, hypode...
# 92  [xtermmap, numlock, definekey, xmodmap, capslo...
# 93  [moscow, aviation, russian, kaliningrad, poljo...
# 94  [boards, solder, mask, green, board, fiberglas...
# 95  [plutonium, nuclear, clancy, bomb, reactors, r...
#
#                                   Representative_Docs
# 0   [\n       There are a couple of ways to look a...
# 1   [Archive-name: x-faq/part4\nLast-modified: 199...
# 2   [News:\n=====\nFor the first time all season, ...
# 3   [\n\nThere was an article in USA today a few m...
# 4   [THE WHITE HOUSE\n\n                    Office...
# ..                                                ...
# 91  [\n\n\tAsk the practitioner whether he uses th...
# 92  [These are two common subjects so I hope someo...
# 93  [\nCorrection, and some more info: The Kalinin...
# 94  [The color of the board shows the composition ...
# 95  [   Doug Holland claims Tom Clancy has provide...
#
# [96 rows x 5 columns]

# %% [markdown]
# ### 8. 임의의 문서에 대한 예측
# -----------------
# 학습된 토픽 모델에 어떤 임의의 문서를 입력하여 해당 문서의 주요 토픽이 무엇인지를 예측하고 싶다면 transform()이라는 메소드를 이용함. 학습에 사용했던 첫번째 문서를 입력으로 하여 해당 문서의 주요 토픽번호를 출력해 보자.

# %%
new_doc = docs[0]

print(new_doc)
# Out:
# I am sure some bashers of Pens fans are pretty confused about the lack
# of any kind of posts about the recent Pens massacre of the Devils. Actually,
# I am  bit puzzled too and a bit relieved. However, I am going to put an end
# to non-PIttsburghers' relief with a bit of praise for the Pens. Man, they
# are killing those Devils worse than I thought. Jagr just showed you why
# he is much better than his regular season stats. He is also a lot
# fo fun to watch in the playoffs. Bowman should let JAgr have a lot of
# fun in the next couple of games since the Pens are going to beat the pulp out of Jersey anyway. I was very disappointed not to see the Islanders lose the final
# regular season game.          PENS RULE!!!

# %%
topics, probs = model.transform([new_doc])
print('예측한 토픽 번호:', topics)
# Out:
# /usr/local/lib/python3.10/dist-packages/scipy/sparse/_index.py:146: SparseEfficiencyWarning:
#
# Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
# 예측한 토픽 번호: [1]

# %% [markdown]
# ### 9. 모델 저장과 로드
# -------------------------------

# %%
model.save("my_topics_model")
BerTopic_model = BERTopic.load("my_topics_model")
